# %% [markdown]
# # IRIS DATASET

# %% [markdown]
# ## Import packages

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## load Dataset

# %%
df=pd.read_csv('https://raw.githubusercontent.com/Apaulgithub/oibsip_task1/main/Iris.csv')
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# ## Data Cleaning

# %%
df.describe(include='all')
# Out:
#                 Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# count   150.000000     150.000000    150.000000     150.000000    150.000000
# unique         NaN            NaN           NaN            NaN           NaN
# top            NaN            NaN           NaN            NaN           NaN
# freq           NaN            NaN           NaN            NaN           NaN
# mean     75.500000       5.843333      3.054000       3.758667      1.198667
# std      43.445368       0.828066      0.433594       1.764420      0.763161
# min       1.000000       4.300000      2.000000       1.000000      0.100000
# 25%      38.250000       5.100000      2.800000       1.600000      0.300000
# 50%      75.500000       5.800000      3.000000       4.350000      1.300000
# 75%     112.750000       6.400000      3.300000       5.100000      1.800000
# max     150.000000       7.900000      4.400000       6.900000      2.500000
#
#             Species
# count           150
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
print('no of rows:',df.shape[0])
print('no of rows:',df.shape[1])
# Out:
# no of rows: 151
# no of rows: 5

# %%
dup=df.duplicated().sum()
print(f'number of duplicated rows are {dup}')
# Out:
# number of duplicated rows are 0

# %%
df.isnull(). sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
df.shape[0]
# Out:
# 150

# %%
df.shape[1]
# Out:
# 6

# %%
# dataset describe (all columns included)

# %%
df.describe(include='all').round(2)
# Out:
#             Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# count   150.00         150.00        150.00         150.00        150.00
# unique     NaN            NaN           NaN            NaN           NaN
# top        NaN            NaN           NaN            NaN           NaN
# freq       NaN            NaN           NaN            NaN           NaN
# mean     75.50           5.84          3.05           3.76          1.20
# std      43.45           0.83          0.43           1.76          0.76
# min       1.00           4.30          2.00           1.00          0.10
# 25%      38.25           5.10          2.80           1.60          0.30
# 50%      75.50           5.80          3.00           4.35          1.30
# 75%     112.75           6.40          3.30           5.10          1.80
# max     150.00           7.90          4.40           6.90          2.50
#
#             Species
# count           150
# unique            3
# top     Iris-setosa
# ...

# %%
# renaming the columns
df.columns=['Sepal length', 'Sepal width', 'Petal length', 'Petal width','class_labels']

# %%
df.head()
# Out:
#    Sepal length  Sepal width  Petal length  Petal width class_labels
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %% [markdown]
# ## Data Visualization

# %%
sns.pairplot(df, hue='class_labels')
plt.show()

# %% [markdown]
# ## Data Splitting

# %%
x=df.drop('class_labels',axis=1)

# %%
x
# Out:
#      Sepal length  Sepal width  Petal length  Petal width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
y=df['class_labels']

# %%
y
# Out:
# 0         Iris-setosa
# 1         Iris-setosa
# 2         Iris-setosa
# 3         Iris-setosa
# 4         Iris-setosa
#             ...
# 145    Iris-virginica
# 146    Iris-virginica
# 147    Iris-virginica
# 148    Iris-virginica
# 149    Iris-virginica
# Name: class_labels, Length: 150, dtype: object

# %% [markdown]
# ## Ploting average of each feature class

# %%
y_data = np.array([
    np.average(x.iloc[:, i][y == j].astype('float32'))  # Average of feature i for class j
    for i in range(x.shape[1])                          # Loop over all feature columns
       for j in np.unique(y)                               # Loop over all unique class labels
])

# %%
print(x.shape[1])        # Number of features (columns)
# Out:
# 4

# %%
# Calculate average of each features for all classes
y_data = np.array([np.average(x.iloc[:, i][y==j].astype('float32')) for i in range (x.shape[1])
 for j in (np.unique(y))])
y_data_reshaped = y_data.reshape(4,3)
y_data_reshaped = np.swapaxes(y_data_reshaped, 0, 1)
x_axis = np.arange(x.shape[1])
width = 0.25

# %%
#plot the average
plt.bar(x_axis, y_data_reshaped[0] ,width, label='setosa')
plt.bar(x_axis+width, y_data_reshaped[1], width, label='versicolour')
plt.bar(x_axis+width*2, y_data_reshaped[2], width, label='virginica')
plt.xticks(x_axis,columns[:4])
plt.xlabel("Features")
plt.ylabel("Value in cm")
plt.legend(bbox_to_anchor=(1.3,1))
plt.show()

# %% [markdown]
# # Model Training

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test= train_test_split(x,y,test_size=0.2)

# %%
from sklearn.svm import SVC
svn=SVC()
svn.fit(x_train, y_train)
# Out:
# SVC()

# %% [markdown]
# # Model Evaluation

# %%
#predict from test dataset
prediction=svn.predict(x_test)

#calculate accuracy
from sklearn.metrics import accuracy_score
accuracy_score(y_test, prediction)
# Out:
# 0.9666666666666667

# %% [markdown]
# ##  detailed classification report

# %%
from sklearn.metrics import classification_report
print(classification_report (y_test, prediction))
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00         8
# Iris-versicolor       1.00      0.92      0.96        12
#  Iris-virginica       0.91      1.00      0.95        10
#
#        accuracy                           0.97        30
#       macro avg       0.97      0.97      0.97        30
#    weighted avg       0.97      0.97      0.97        30

# %% [markdown]
# # Testing the model

# %%
x_new=np.array([
    [3,2,1,0.2],
    [4.9,2.2,3.8,1.1],
    [5.3,2.5,4.6,1.9],
    [3.7,2.1,3.1,1.9]
])
prediction=svn.predict(x_new)
print("Prediction of Species: {}".format(prediction))
# Out:
# Prediction of Species: ['Iris-setosa' 'Iris-versicolor' 'Iris-virginica' 'Iris-versicolor']
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(

# %%
# Save the model
import pickle
with open('SVM.pickle', 'wb') as f:
    pickle.dump(svn, f)

# Load the model
with open('SVM.pickle', 'rb') as f:
    model = pickle.load(f)
model.predict(x_new)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica',
#        'Iris-versicolor'], dtype=object)
